# %%
import csv
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from pathlib import Path
from google.cloud import storage
import os
import time
import re

# Google Cloud project and storage details
project_id = "dylanericsp25"
region = "us-central1"
bucket_name = "movies-entertainment"
gcs_in_folder = "initial-loads/imdb-reviews/"
local_folder = "out-csv"
gcs_out_folder = "initial-loads/imdb-reviews/out"
model_name = "gemini-1.5-flash-001"

# Ensure local folder exists
os.makedirs(local_folder, exist_ok=True)

# Prompt to extract structured review data
prompt = """
You are extracting structured IMDb movie review data. Extract **only the following fields**:

1. **Movie Name**: Extract the correct movie name. If unclear, use the filename without ".txt".
2. **Sentiment**: "Positive", "Negative", or "Neutral".
3. **Key Themes**: Identify up to 3 themes ("Cinematography", "Acting", "Plot", "Soundtrack"); separate using semicolons (`;`).
4. **Named Entities**: Extract actors, directors, and studios (separate using `;`).
5. **Emotional Tone**: Choose from: "Excitement", "Disappointment", "Nostalgia", "Frustration", or "Satisfaction".
6. **Star Rating**: Extract **only numerical ratings** (e.g., `"7/10"`, `"4 stars"`, `"3.5/5"`). If missing, return `"N/A"`.

### **STRICT CSV FORMAT**
- **Return EXACTLY in this format:**
  `"movie_name","sentiment","key_themes","named_entities","emotional_tone","star_rating"`
- **Use DOUBLE QUOTES (`""`) around all text fields.**
- **Commas (`,`) must only separate fields, never inside values.**
- **If a field is missing, return `"N/A"` (not empty).**
- **DO NOT include extra explanations, markdown, or new lines.**

### **Example Correct Output**
For *Inception* (2010):
"Inception","Positive","Cinematography;Plot;Acting","Leonardo DiCaprio (Actor); Christopher Nolan (Director); Warner Bros (Studio)","Excitement","9/10"
Ensure perfect adherence to this format.
"""








def clean_star_rating(rating):
    """Ensure star ratings are formatted correctly (e.g., '7/10', '4 stars')."""
    match = re.search(r'(\d+(\.\d+)?)(/10| stars|/5)?', rating)  # Extract only valid numerical ratings
    return match.group(0) if match else "N/A"

def format_row(row, filename):
    """Ensure CSV output from Gemini is parsed correctly without shifts."""
    try:
        csv_reader = csv.reader([row], quotechar='"', delimiter=',', skipinitialspace=True)
        parsed_row = next(csv_reader)  # Extract parsed row

        # Ensure exactly 6 expected columns
        while len(parsed_row) < 6:
            parsed_row.append("N/A")
        if len(parsed_row) > 6:
            parsed_row = parsed_row[:6]

        # Fix star rating format
        parsed_row[5] = clean_star_rating(parsed_row[5])

        return [filename] + parsed_row

    except Exception as e:
        print(f"❌ Error formatting row: {row} | {e}")
        return [filename, "N/A", "N/A", "N/A", "N/A", "N/A", "N/A"]  # Default fallback




def main():
    """Process IMDb reviews from GCS and extract structured insights using Gemini AI."""
    vertexai.init(project=project_id, location=region)
    model = GenerativeModel(model_name)
    storage_client = storage.Client()
    
    # Fetch all .txt files in GCS
    blobs = [blob for blob in storage_client.list_blobs(bucket_name, prefix=gcs_in_folder) if blob.name.endswith(".txt")]
    print(f"✅ Found {len(blobs)} review files in GCS bucket.")

    if not blobs:
        print("❌ No valid review files found. Check the GCS bucket.")
        return
    
    all_reviews = []
    batch_size = 5  # Process files in small batches to manage rate limits

    for i in range(0, len(blobs), batch_size):  # Limit to first 10 files
        batch = blobs[i : i + batch_size]

        for blob in batch:
            print(f"Processing file: {blob.name}")
            filename = blob.name.split("/")[-1]
            movie_name = filename.replace(".txt", "").replace("_", " ").strip()

            print(f"🎬 Extracting insights for: {movie_name}")

            # Read IMDb review text from GCS
            review_text = blob.download_as_text().strip()
            if not review_text:
                print(f"❌ Skipping {movie_name} (empty file).")
                continue

            # Send to Gemini model for processing
            text_input = Part.from_text(review_text)
            try:
                time.sleep(2)  # Prevent exceeding API quota
                response = model.generate_content([text_input, prompt])
                csv_output = response.text.replace("```csv", "").replace("```", "").strip()

                # Save raw Gemini response for debugging
                with open(f"{local_folder}/raw_{filename}.txt", "w", encoding="utf-8") as f:
                    f.write(csv_output)

                print(f"🔹 Gemini Full Response for {filename}: {csv_output}")  # Print full response
            except Exception as e:
                if "Quota exceeded" in str(e):
                    print(f"❌ Skipping {filename} due to quota limits. Consider increasing quota.")
                else:
                    print(f"❌ Error processing {filename}: {e}")
                continue

            # Ensure valid response format
            csv_lines = [line for line in csv_output.split("\n") if "filename" not in line]  # Remove headers if present

            for row in csv_lines:
                formatted_row = format_row(row, filename)
                all_reviews.append(formatted_row)





    # Prevent saving an empty file
    if not all_reviews:
        print("❌ No valid reviews processed. Skipping CSV upload.")
        return
    
    # Save all reviews in one CSV file
    output_csv_path = f"{local_folder}/all_imdb_reviews.csv"
    with open(output_csv_path, "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["filename", "movie_name", "sentiment", "key_themes", "named_entities", "emotional_tone", "star_rating"])
        writer.writerows(all_reviews)




def copy_to_GCS():
    """Uploads the combined IMDb review CSV to GCS."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    
    file_path = f"{local_folder}/all_imdb_reviews.csv"
    blob_name = f"{gcs_out_folder}/all_imdb_reviews.csv"

    # Ensure file exists before uploading
    if not os.path.exists(file_path) or os.stat(file_path).st_size == 0:
        print("❌ CSV file is missing or empty. Skipping upload.")
        return

    blob = bucket.blob(blob_name)
    blob.upload_from_filename(file_path)

    print(f"✅ Uploaded single combined file: {blob_name}")


if __name__ == "__main__":
    main()
    copy_to_GCS()
# Out:
# ✅ Found 1256 review files in GCS bucket.
# Processing file: initial-loads/imdb-reviews/neg/1000_3.txt
# 🎬 Extracting insights for: 1000 3
# 🔹 Gemini Full Response for 1000_3.txt: "N/A","Negative","Plot;Acting","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/100_4.txt
# 🎬 Extracting insights for: 100 4
# 🔹 Gemini Full Response for 100_4.txt: "N/A","Negative","Acting;Plot","Adrian Paul (Actor);","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/104_1.txt
# 🎬 Extracting insights for: 104 1
# 🔹 Gemini Full Response for 104_1.txt: "N/A","Negative","Plot;Acting;Cinematography","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/105_3.txt
# 🎬 Extracting insights for: 105 3
# 🔹 Gemini Full Response for 105_3.txt: "The Forgotten (AKA: Don't Look In The Basement)","Negative","Acting;Plot;Cinematography","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/106_3.txt
# 🎬 Extracting insights for: 106 3
# 🔹 Gemini Full Response for 106_3.txt: "Dr. Stevens","Negative","Plot;Acting;Cinematography","Micheal Harvey (Actor); Hugh Feagin (Actor); Camilla Carr (Actor); Gene Ross (Actor); Rosie Holotik (Actor); Annabelle Weenick (Actor); Rhea MacAdams (Actor); S.f. Brownrigg (Director); Tim Pope (Writer)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/119_3.txt
# 🎬 Extracting insights for: 119 3
# 🔹 Gemini Full Response for 119_3.txt: "N/A","Negative","Acting;Plot;N/A","Jean-Claude Van Damme (Actor); Isaac Florentine (Director); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/11_3.txt
# 🎬 Extracting insights for: 11 3
# 🔹 Gemini Full Response for 11_3.txt: "Darling Lili","Negative","Acting;Plot;Soundtrack","Julie Andrews (Actor); Blake Edwards (Director); Rock Hudson (Actor); William Peter Blatty (Writer)","Disappointment","1/2"
# Processing file: initial-loads/imdb-reviews/neg/120_2.txt
# 🎬 Extracting insights for: 120 2
# 🔹 Gemini Full Response for 120_2.txt: "N/A","Negative","Plot;Acting;Cinematography","Jean-Claude Van Damme (Actor); Scott Adkins (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/122_4.txt
# 🎬 Extracting insights for: 122 4
# 🔹 Gemini Full Response for 122_4.txt: "The Shepherd : Border Patrol","Negative","Acting;Plot;Cinematography","Jean-Claude Van Damme (Actor); N/A (Director); N/A (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/124_2.txt
# 🎬 Extracting insights for: 124 2
# 🔹 Gemini Full Response for 124_2.txt: "The Shepherd","Negative","Acting;Plot;Cinematography","Jean Claude Van Damme (Actor); Stephen Lord (Actor); Isaac Florentine (Director)","Disappointment","*"
# Processing file: initial-loads/imdb-reviews/neg/126_4.txt
# 🎬 Extracting insights for: 126 4
# 🔹 Gemini Full Response for 126_4.txt: "N/A","Neutral","Plot;Acting;N/A","Van Damme (Actor);N/A;N/A","Satisfaction","4"
# Processing file: initial-loads/imdb-reviews/neg/139_4.txt
# 🎬 Extracting insights for: 139 4
# 🔹 Gemini Full Response for 139_4.txt: "Sword in the Moon","Negative","Cinematography;Plot;Acting","Cho Jae Hyun (Actor); Choi (Actor); Shi Yeong (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/13_1.txt
# 🎬 Extracting insights for: 13 1
# 🔹 Gemini Full Response for 13_1.txt: "N/A","Negative","Plot;Acting","Julie; Blake; Rock","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/140_2.txt
# 🎬 Extracting insights for: 140 2
# 🔹 Gemini Full Response for 140_2.txt: "Black Emanuelle","Negative","Cinematography;Acting;Plot","Laura Gemser (Actor); Karin Schubert (Actor); Albert Thomas (Director)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/141_1.txt
# 🎬 Extracting insights for: 141 1
# 🔹 Gemini Full Response for 141_1.txt: "N/A","Negative","Acting;Plot;Soundtrack","Gemser (Actor);Warner? (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/143_4.txt
# 🎬 Extracting insights for: 143 4
# 🔹 Gemini Full Response for 143_4.txt: "Gen-Y Cops The Next Generation","Negative","Plot;Acting;Special Effects","Paul Rudd (Actor); N/A; N/A","Disappointment","4"
# Processing file: initial-loads/imdb-reviews/neg/145_1.txt
# 🎬 Extracting insights for: 145 1
# 🔹 Gemini Full Response for 145_1.txt: "N/A","Negative","Acting;Plot","Edison Chen (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/158_1.txt
# 🎬 Extracting insights for: 158 1
# 🔹 Gemini Full Response for 158_1.txt: "N/A","Negative","Acting;Plot","Jane Fonda (Actor);","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/15_2.txt
# 🎬 Extracting insights for: 15 2
# 🔹 Gemini Full Response for 15_2.txt: "Fire","Negative","Acting;Plot;Cinematography","Deepa Mehta (Director); Nandita Das (Actor); Shabana Azmi (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/161_3.txt
# 🎬 Extracting insights for: 161 3
# 🔹 Gemini Full Response for 161_3.txt: "The Edge of Love","Negative","Cinematography;Acting;Plot","Keira Knightley (Actor); Sienna Miller (Actor); John Maybury (Director); N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/163_1.txt
# 🎬 Extracting insights for: 163 1
# 🔹 Gemini Full Response for 163_1.txt: "N/A","Negative","Plot;Acting","Keira Knightley (Actor); Cillian Murphy (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/165_4.txt
# 🎬 Extracting insights for: 165 4
# 🔹 Gemini Full Response for 165_4.txt: "N/A","Negative","Plot;Acting;N/A","Keira Knightley (Actor); Dylan Thomas (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/167_2.txt
# 🎬 Extracting insights for: 167 2
# 🔹 Gemini Full Response for 167_2.txt: "N/A","Negative","Acting;Plot;Cinematography","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/178_2.txt
# 🎬 Extracting insights for: 178 2
# 🔹 Gemini Full Response for 178_2.txt: "Mondovino","Negative","Cinematography;Plot","N/A","Frustration","2/10"
# Processing file: initial-loads/imdb-reviews/neg/17_3.txt
# 🎬 Extracting insights for: 17 3
# 🔹 Gemini Full Response for 17_3.txt: "Thirst","Negative","Plot;Acting;Cinematography","Park Chan-wook (Director); Song Kang-ho (Actor); Kim Ok-vin (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/183_4.txt
# 🎬 Extracting insights for: 183 4
# 🔹 Gemini Full Response for 183_4.txt: "Aab Tak Chhappan","Negative","Plot;Acting","Daya Nayak (Actor); Ram Gopal Varma (Director)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/185_4.txt
# 🎬 Extracting insights for: 185 4
# 🔹 Gemini Full Response for 185_4.txt: "N/A","Negative","Acting;Plot;Fighting","Mathias Hues (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/187_1.txt
# 🎬 Extracting insights for: 187 1
# 🔹 Gemini Full Response for 187_1.txt: "The Last Crusade","Negative","Acting;Plot;N/A","Sean Connery (Actor); Harrison Ford (Actor); Steven Spielberg (Director)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/201_2.txt
# 🎬 Extracting insights for: 201 2
# 🔹 Gemini Full Response for 201_2.txt: "N/A","Negative","Acting;Plot;Production","Flex (Actor); Tangi (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/202_4.txt
# 🎬 Extracting insights for: 202 4
# 🔹 Gemini Full Response for 202_4.txt: "N/A","Negative","Acting;Plot;Cinematography","Matt Damon (Actor); Lawrence Fishbourne (Actor); Jean Reno (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/203_3.txt
# 🎬 Extracting insights for: 203 3
# 🔹 Gemini Full Response for 203_3.txt: "Armored","Negative","Plot;Acting;N/A","Columbus Short (Actor); Matt Dillon (Actor); Jean Reno (Actor); Laurence Fishburne (Actor); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/207_3.txt
# 🎬 Extracting insights for: 207 3
# 🔹 Gemini Full Response for 207_3.txt: "N/A","Negative","Soundtrack;Acting;Plot","Matt Dillon (Actor); N/A (Director); N/A (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/218_3.txt
# 🎬 Extracting insights for: 218 3
# 🔹 Gemini Full Response for 218_3.txt: "N/A","Negative","Acting;Plot","Laurence Fishbourne (Actor); Columbus Short (Actor); Milo Ventimiglia (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/223_3.txt
# 🎬 Extracting insights for: 223 3
# 🔹 Gemini Full Response for 223_3.txt: "Armored","Negative","Plot;Acting","Columbus Short (Actor); Matt Dillon (Actor); Lawrence Fishbourne (Actor); Jean Reno (Actor); James V. Simpson (Screenwriter)","Frustration","3/10"
# Processing file: initial-loads/imdb-reviews/neg/225_3.txt
# 🎬 Extracting insights for: 225 3
# 🔹 Gemini Full Response for 225_3.txt: "Fool for Love","Negative","Acting;Soundtrack;Plot","Sam Shepard (Actor); Robert Altman (Director); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/227_1.txt
# 🎬 Extracting insights for: 227 1
# 🔹 Gemini Full Response for 227_1.txt: "N/A","Negative","Acting;Plot;Cinematography","Bruce Willis (Actor); N/A (Director); N/A (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/238_1.txt
# 🎬 Extracting insights for: 238 1
# 🔹 Gemini Full Response for 238_1.txt: "The Robot vs. the Aztec Mummy","Negative","Plot;Acting","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/239_2.txt
# 🎬 Extracting insights for: 239 2
# 🔹 Gemini Full Response for 239_2.txt: "N/A","Negative","Plot;Acting","MST3K (Show); Captain Cody (Character)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/240_4.txt
# 🎬 Extracting insights for: 240 4
# 🔹 Gemini Full Response for 240_4.txt: "N/A","Positive","Plot;Acting","N/A","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/neg/242_3.txt
# 🎬 Extracting insights for: 242 3
# 🔹 Gemini Full Response for 242_3.txt: "The Mummy","Positive","Plot;Acting;Dialogue","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/244_2.txt
# 🎬 Extracting insights for: 244 2
# 🔹 Gemini Full Response for 244_2.txt: "N/A","Negative","Plot;Acting;Cinematography","Luis Aceves Castaneda (Actor); Rafael Portillo (Director); Alfredo Salazar (Writer); Guillermo Calderon (Writer)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/246_2.txt
# 🎬 Extracting insights for: 246 2
# 🔹 Gemini Full Response for 246_2.txt: "Android vs. the Aztec Mummy","Negative","Plot;Cinematography","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/258_1.txt
# 🎬 Extracting insights for: 258 1
# 🔹 Gemini Full Response for 258_1.txt: "The Wedding Singer Remake","Negative","Plot;Acting","Adam Sandler (Actor); Drew Barrymore (Actor); N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/259_2.txt
# 🎬 Extracting insights for: 259 2
# 🔹 Gemini Full Response for 259_2.txt: "Aa Meri Life Bana De","Negative","Acting;Plot;Soundtrack","Salman Khan (Actor); Rani Mukerji (Actor); Pooja Batra (Actor); Jackie Shroff (Actor); Kashmira Shah (Actor); Raveena Tandon (Actor); Mohnish Behl (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/260_1.txt
# 🎬 Extracting insights for: 260 1
# 🔹 Gemini Full Response for 260_1.txt: "Bandhan","Negative","Acting;Plot;Soundtrack","Salman Khan (Actor); Jackie Shroff (Actor); Rani Mukherjee (Actor); Pooja Bhatra (Actor); Kashmira Shah (Actor); Mohinish Behl (Actor); Inder Kumar (Actor); Shakti Kapoor (Actor); K Murli Mohan Rao (Director)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/262_1.txt
# 🎬 Extracting insights for: 262 1
# 🔹 Gemini Full Response for 262_1.txt: "N/A","Negative","Acting;Plot;Soundtrack","Larry Miller (Actor);N/A;N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/264_1.txt
# 🎬 Extracting insights for: 264 1
# 🔹 Gemini Full Response for 264_1.txt: "Mishima: A Life in Four Chapters","Negative","Acting;Plot;Soundtrack","Paul Schrader (Director); Philip Glass (Composer); Yukio Mishima (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/266_4.txt
# 🎬 Extracting insights for: 266 4
# 🔹 Gemini Full Response for 266_4.txt: "Oceans 12","Negative","Acting;Plot;Cinematography","Brad Pitt (Actor); Catherine Zeta-Jones (Actor); George Clooney (Actor); Matt Damon (Actor); Steven Soderbergh (Director)","Disappointment","4/10"
# Processing file: initial-loads/imdb-reviews/neg/267_1.txt
# 🎬 Extracting insights for: 267 1
# 🔹 Gemini Full Response for 267_1.txt: "Ocean's Twelve","Negative","Plot;Acting","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/279_1.txt
# 🎬 Extracting insights for: 279 1
# 🔹 Gemini Full Response for 279_1.txt: "Ocean's 12","Negative","Acting;Plot;Cinematography","Julia Roberts (Actor); Catherine Zeta-Jones (Actor); Matt Damon (Actor); George Clooney (Actor); Brad Pitt (Actor); Bruce Willis (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/280_1.txt
# 🎬 Extracting insights for: 280 1
# 🔹 Gemini Full Response for 280_1.txt: "Ocean's 12","Negative","Acting;Plot;Cinematography","Matt Damon (Actor); Brad Pitt (Actor); George Clooney (Actor); Steven Soderbergh (Director); Warner Bros (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/284_2.txt
# 🎬 Extracting insights for: 284 2
# 🔹 Gemini Full Response for 284_2.txt: "N/A","Negative","Cinematography;Acting;Plot","Julia Roberts (Actor); Catherine Zeta Jones (Actor); George Clooney (Actor); Brad Pitt (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/286_1.txt
# 🎬 Extracting insights for: 286 1
# 🔹 Gemini Full Response for 286_1.txt: "Ocean's Twelve","Negative","Plot;Acting","George Clooney (Actor); Brad Pitt (Actor); Julia Roberts (Actor); Andy Garcia (Actor); Bernie Mac (Actor); Catherine Zeta-Jones (Actor); Steven Soderbergh (Director); Warner Bros (Studio)","Disappointment","1/10"
# Processing file: initial-loads/imdb-reviews/neg/28_3.txt
# 🎬 Extracting insights for: 28 3
# 🔹 Gemini Full Response for 28_3.txt: "N/A","Negative","Acting;Plot;Soundtrack","Rita Hayworth (Actor); Gene Kelly (Actor); Phil Silvers (Actor); Eve Arden (Actor)","Disappointment","1/2"
# Processing file: initial-loads/imdb-reviews/neg/299_1.txt
# 🎬 Extracting insights for: 299 1
# 🔹 Gemini Full Response for 299_1.txt: "Hoods","Negative","Acting;Plot;N/A","Joe Mantegna (Actor); Kevin Pollack (Actor); Joe Pantoliano (Actor); Jennifer Tilly (Actor); Seymour Cassel (Actor); Mark Malone (Writer/Director); Arthur Penn (Director); Seville (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/300_1.txt
# 🎬 Extracting insights for: 300 1
# 🔹 Gemini Full Response for 300_1.txt: "Dahmer","Negative","Acting;Plot;N/A","Carl Crew (Actor); N/A; N/A","Disappointment","1/10"
# Processing file: initial-loads/imdb-reviews/neg/301_4.txt
# 🎬 Extracting insights for: 301 4
# 🔹 Gemini Full Response for 301_4.txt: "Dahmer - Monster: The Jeffrey Dahmer Story","Negative","Acting;Plot;N/A","N/A","Frustration","4/10"
# Processing file: initial-loads/imdb-reviews/neg/302_3.txt
# 🎬 Extracting insights for: 302 3
# 🔹 Gemini Full Response for 302_3.txt: "The Secret Life: Jeffrey Dahmer","Negative","Acting;Plot;N/A","Carl Crew (Actor); N/A; N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/303_2.txt
# 🎬 Extracting insights for: 303 2
# 🔹 Gemini Full Response for 303_2.txt: "N/A","Neutral","Acting;Plot;Cinematography","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/305_2.txt
# 🎬 Extracting insights for: 305 2
# 🔹 Gemini Full Response for 305_2.txt: "N/A","Negative","Plot;Acting","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/307_1.txt
# 🎬 Extracting insights for: 307 1
# 🔹 Gemini Full Response for 307_1.txt: "N/A","Negative","Plot;Acting","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/318_3.txt
# 🎬 Extracting insights for: 318 3
# 🔹 Gemini Full Response for 318_3.txt: "N/A","Neutral","Acting;Plot;Special Effects","Linnea Quigley (Actor)","Nostalgia","3/10"
# Processing file: initial-loads/imdb-reviews/neg/321_1.txt
# 🎬 Extracting insights for: 321 1
# 🔹 Gemini Full Response for 321_1.txt: Please provide me with the IMDb movie review data you'd like me to analyze. I'm ready to extract the information you need in the correct CSV format.
# Processing file: initial-loads/imdb-reviews/neg/323_2.txt
# 🎬 Extracting insights for: 323 2
# 🔹 Gemini Full Response for 323_2.txt: "Jack-O","Negative","Plot;Acting;N/A","Linnea Quigley (Actor); John Carradine (Actor); Cameron Mitchell (Actor); Brinke Stevens (Actor); Retromedia (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/325_1.txt
# 🎬 Extracting insights for: 325 1
# 🔹 Gemini Full Response for 325_1.txt: "N/A","Negative","Acting;Plot","N/A","Frustration","1"
# Processing file: initial-loads/imdb-reviews/neg/338_1.txt
# 🎬 Extracting insights for: 338 1
# 🔹 Gemini Full Response for 338_1.txt: "N/A","Negative","Cinematography;Acting;Plot","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/33_3.txt
# 🎬 Extracting insights for: 33 3
# 🔹 Gemini Full Response for 33_3.txt: "Jacqueline Hyde","Negative","Acting;Plot;N/A","Jacqueline Hyde (Actor);N/A;N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/340_2.txt
# 🎬 Extracting insights for: 340 2
# 🔹 Gemini Full Response for 340_2.txt: "N/A","Negative","Plot;Acting;Cinematography","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/342_1.txt
# 🎬 Extracting insights for: 342 1
# 🔹 Gemini Full Response for 342_1.txt: "N/A","Negative","Acting;Plot;Cinematography","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/344_4.txt
# 🎬 Extracting insights for: 344 4
# 🔹 Gemini Full Response for 344_4.txt: "N/A","Negative","Plot;Special Effects","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/345_3.txt
# 🎬 Extracting insights for: 345 3
# 🔹 Gemini Full Response for 345_3.txt: "N/A","Neutral","Cinematography;Acting;Plot","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/346_2.txt
# 🎬 Extracting insights for: 346 2
# 🔹 Gemini Full Response for 346_2.txt: "N/A","Positive","Acting;Plot","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/347_1.txt
# 🎬 Extracting insights for: 347 1
# 🔹 Gemini Full Response for 347_1.txt: "Screamers","Negative","Plot","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/34_1.txt
# 🎬 Extracting insights for: 34 1
# 🔹 Gemini Full Response for 34_1.txt: "Jacqueline Hyde","Negative","Cinematography;Acting;Plot","Gabriella Hall (Co-Producer); Robert Donovan (Actor); Malcolm Bennett (Actor); Blythe Metz (Actor); Rolfe Kanefsky (Writer, Co-Producer, Director)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/358_4.txt
# 🎬 Extracting insights for: 358 4
# 🔹 Gemini Full Response for 358_4.txt: "Class Warfare","Negative","Acting;Plot","Lindsey McKeon (Actor); Robin Dunne (Actor); Wade Carpenter (Actor); Dave McGowan (Actor)","Disappointment","4/10"
# Processing file: initial-loads/imdb-reviews/neg/359_4.txt
# 🎬 Extracting insights for: 359 4
# 🔹 Gemini Full Response for 359_4.txt: "The Man with the Golden Arm","Negative","Plot;Acting;Soundtrack","Frank Sinatra (Actor); Eliot Elisofon (Director); 20th Century Fox (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/362_2.txt
# 🎬 Extracting insights for: 362 2
# 🔹 Gemini Full Response for 362_2.txt: "N/A","Negative","Plot;Acting","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/364_1.txt
# 🎬 Extracting insights for: 364 1
# 🔹 Gemini Full Response for 364_1.txt: "N/A","Negative","Acting;Plot;Cinematography","C Thomas Howell (Actor); N/A (Director); N/A (Studio)","Frustration","1/10"
# Processing file: initial-loads/imdb-reviews/neg/366_1.txt
# 🎬 Extracting insights for: 366 1
# 🔹 Gemini Full Response for 366_1.txt: "N/A","Negative","Acting;Plot;Costumes","Roddy Piper (Actor); David Carradine (Actor); N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/36_3.txt
# 🎬 Extracting insights for: 36 3
# 🔹 Gemini Full Response for 36_3.txt: "Black Voodoo","Negative","Plot;Acting;N/A","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/379_1.txt
# 🎬 Extracting insights for: 379 1
# 🔹 Gemini Full Response for 379_1.txt: "Beastmaster 2: Through the Portal of Time","Negative","Plot;Acting","Marc Singer (Actor);  (Director); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/37_1.txt
# 🎬 Extracting insights for: 37 1
# 🔹 Gemini Full Response for 37_1.txt: "Hospital Of Terror","Negative","Acting;Plot;Cinematography","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/380_2.txt
# 🎬 Extracting insights for: 380 2
# 🔹 Gemini Full Response for 380_2.txt: "Masters of the Universe","Negative","Acting;Plot;N/A","Robert Z'Dar (Actor); Marc Singer (Actor); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/384_4.txt
# 🎬 Extracting insights for: 384 4
# 🔹 Gemini Full Response for 384_4.txt: "Cat in the Brain","Negative","Plot;Acting;Gore","Lucio Fulci (Director); David L. Thompson (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/387_1.txt
# 🎬 Extracting insights for: 387 1
# 🔹 Gemini Full Response for 387_1.txt: "Closet Land","Negative","Acting;Plot","Alan Rickman (Actor); Jennifer Jason Leigh (Actor); Peter Greenaway (Director); Miramax Films (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/399_1.txt
# 🎬 Extracting insights for: 399 1
# 🔹 Gemini Full Response for 399_1.txt: "N/A","Negative","Plot;Acting","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/410_2.txt
# 🎬 Extracting insights for: 410 2
# 🔹 Gemini Full Response for 410_2.txt: "Angels and Demons","Negative","Acting;Plot;Cinematography","Tom Hanks (Actor); Ron Howard (Director); Columbia Pictures (Studio); Imagine Entertainment (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/413_4.txt
# 🎬 Extracting insights for: 413 4
# 🔹 Gemini Full Response for 413_4.txt: "Angels & Demons","Negative","Acting;Plot","Tom Hanks (Actor); Ewan McGregor (Actor); Ayelet Zurer (Actor); Camren Argenziano (Actor); Ron Howard (Director); Nikolaj Lie Kaas (Actor); Pierfrancesco Favino (Actor)","Disappointment","4/10"
# Processing file: initial-loads/imdb-reviews/neg/415_1.txt
# 🎬 Extracting insights for: 415 1
# 🔹 Gemini Full Response for 415_1.txt: "Angels & Demons","Negative","Plot;Acting;N/A","Ron Howard (Director); Tom Hanks (Actor); Ewan McGregor (Actor); Ayelet Zurer (Actor);  Columbia Pictures (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/417_1.txt
# 🎬 Extracting insights for: 417 1
# 🔹 Gemini Full Response for 417_1.txt: "Angels and Demons","Negative","Plot;Cinematography;Soundtrack","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/428_3.txt
# 🎬 Extracting insights for: 428 3
# 🔹 Gemini Full Response for 428_3.txt: "An American Werewolf in Paris","Negative","Cinematography;Acting;Plot","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/430_4.txt
# 🎬 Extracting insights for: 430 4
# 🔹 Gemini Full Response for 430_4.txt: "An American Werewolf in London (1997)","Negative","Plot;Acting;FX","David Naughton (Actor); John Landis (Director); Universal Pictures (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/431_2.txt
# 🎬 Extracting insights for: 431 2
# 🔹 Gemini Full Response for 431_2.txt: "An American Werewolf in Paris","Negative","Plot;Acting;Cinematography","Thomas Everett Scott (Actor); Julie Delpy (Actor);  John Landis (Director); Universal Pictures (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/433_1.txt
# 🎬 Extracting insights for: 433 1
# 🔹 Gemini Full Response for 433_1.txt: "N/A","Negative","Acting;Plot","Cory Feldman (Actor); Shades (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/435_1.txt
# 🎬 Extracting insights for: 435 1
# 🔹 Gemini Full Response for 435_1.txt: "American Werewolf in Paris","Negative","Acting;Plot;Special Effects","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/437_2.txt
# 🎬 Extracting insights for: 437 2
# 🔹 Gemini Full Response for 437_2.txt: "AWiP","Negative","Acting;Plot;Special Effects","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/449_3.txt
# 🎬 Extracting insights for: 449 3
# 🔹 Gemini Full Response for 449_3.txt: "Larry King Live","Negative","N/A","Larry King (Actor); Bill Maher (Actor); Dr. Phil (Actor); Billy Graham (Actor); O.J. Simpson (Actor); Anna Nicole Smith (Actor); Paris Hilton (Actor); Britney Spears (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/450_2.txt
# 🎬 Extracting insights for: 450 2
# 🔹 Gemini Full Response for 450_2.txt: "Larry King Live","Negative","Acting;Plot","Larry King (Actor); CNN (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/452_2.txt
# 🎬 Extracting insights for: 452 2
# 🔹 Gemini Full Response for 452_2.txt: "Rose","Negative","Plot;Acting;Pacing","N/A","Frustration","N/A"
# "The End of the World","Negative","Plot;Pacing","N/A","Frustration","N/A"
# "The Unquiet Dead","Negative","Plot;Acting","N/A","Frustration","N/A"
# "Aliens of London/World War Three","Negative","Plot;Acting;Pacing","Penelope Wilton (Actor)","Frustration","N/A"
# "Dalek","Negative","Plot;Acting;Pacing","N/A","Disappointment","N/A"
# "The Long Game","Negative","Plot;Pacing","N/A","Frustration","N/A"
# "Father's Day","Negative","Plot;Acting","N/A","Disappointment","N/A"
# "The Empty Child/The Doctor Dances","Neutral","Plot;Acting;Pacing","Florence Hoath (Actor)","Frustration","N/A"
# "Boom Town","Negative","N/A","N/A","Disappointment","N/A"
# "Bad Wolf","Negative","Plot;Pacing","N/A","Disappointment","N/A"
# "The Parting of the Ways","Negative","Plot;Acting;Pacing","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/454_1.txt
# 🎬 Extracting insights for: 454 1
# 🔹 Gemini Full Response for 454_1.txt: "The One","Negative","Plot;Acting;N/A","Andre Harrell (Music Expert); Kate Hudson (Music Expert); George Stroumboulopoulos (Host); Paula Abdul (Music Expert)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/468_1.txt
# 🎬 Extracting insights for: 468 1
# 🔹 Gemini Full Response for 468_1.txt: "Darwin","Negative","Plot;Acting;N/A","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/470_4.txt
# 🎬 Extracting insights for: 470 4
# 🔹 Gemini Full Response for 470_4.txt: "Creation","Negative","Plot;Acting;N/A","Paul Bettany (Actor); Jennifer Connelly (Actor); Jonathan Kent (Director)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/472_4.txt
# 🎬 Extracting insights for: 472 4
# 🔹 Gemini Full Response for 472_4.txt: "Man with the Screaming Brain","Negative","Plot;Acting;Direction","Bruce Campbell (Actor); Bruce Campbell (Director); Ted Raimi (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/473_1.txt
# 🎬 Extracting insights for: 473 1
# 🔹 Gemini Full Response for 473_1.txt: "Bubba Ho-Tep","Negative","Plot;Acting;Cinematography","Bruce Campbell (Actor);Ted Raimi (Director);N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/474_4.txt
# 🎬 Extracting insights for: 474 4
# 🔹 Gemini Full Response for 474_4.txt: "Running Time","Negative","Acting;Cinematography;Plot","Bruce Campbell (Actor); Ted Raimi (Actor); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/476_1.txt
# 🎬 Extracting insights for: 476 1
# 🔹 Gemini Full Response for 476_1.txt: "The Man With The Screaming Brain","Negative","Acting;Plot","Bruce Campbell (Actor); Ted Raimi (Actor); Stacy Keach (Actor)","Disappointment","3"
# Processing file: initial-loads/imdb-reviews/neg/488_4.txt
# 🎬 Extracting insights for: 488 4
# 🔹 Gemini Full Response for 488_4.txt: "Del Lord's Last Stand","Negative","Plot;Acting","Del Lord (Director); Shemp Howard (Actor); Jules White (Director); Moe Howard (Actor); Larry Fine (Actor)","Disappointment","C-"
# Processing file: initial-loads/imdb-reviews/neg/489_1.txt
# 🎬 Extracting insights for: 489 1
# 🔹 Gemini Full Response for 489_1.txt: "Drawn By Pain","Negative","Acting;Cinematography;Plot","Jesse (Director); N/A; N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/490_2.txt
# 🎬 Extracting insights for: 490 2
# 🔹 Gemini Full Response for 490_2.txt: "N/A","Negative","Soundtrack;Acting","Bon Jovi;Mötley Crue","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/492_1.txt
# 🎬 Extracting insights for: 492 1
# 🔹 Gemini Full Response for 492_1.txt: "N/A","Negative","Plot;Acting","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/496_3.txt
# 🎬 Extracting insights for: 496 3
# 🔹 Gemini Full Response for 496_3.txt: "9 Souls","Negative","Cinematography;Plot;Acting","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/49_4.txt
# 🎬 Extracting insights for: 49 4
# 🔹 Gemini Full Response for 49_4.txt: "Frightmare","Negative","Plot;Acting;Cinematography","Jeffrey Combs (Actor); N/A (Director); N/A (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/508_4.txt
# 🎬 Extracting insights for: 508 4
# 🔹 Gemini Full Response for 508_4.txt: "Heaven's Gate","Negative","Cinematography;Acting;Plot","Stephen Bach (Producer); Michael Cimino (Director); Clint Eastwood (Actor); Jeff Bridges (Actor); Kris Kristofferson (Actor); John Hurt (Actor); Asa Mercer (Author)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/50_3.txt
# 🎬 Extracting insights for: 50 3
# 🔹 Gemini Full Response for 50_3.txt: "N/A","Negative","Plot;Acting","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/511_3.txt
# 🎬 Extracting insights for: 511 3
# 🔹 Gemini Full Response for 511_3.txt: "N/A","Negative","Plot;Acting;Cinematography","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/513_1.txt
# 🎬 Extracting insights for: 513 1
# 🔹 Gemini Full Response for 513_1.txt: "Night Hunter","Negative","Acting;Cinematography;Plot","Don Wilson (Actor); Melanie Smith (Actor); Roger Corman (Director)","Disappointment","1/2*"
# Processing file: initial-loads/imdb-reviews/neg/515_1.txt
# 🎬 Extracting insights for: 515 1
# 🔹 Gemini Full Response for 515_1.txt: "N/A","Negative","Plot;Acting","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/51_4.txt
# 🎬 Extracting insights for: 51 4
# 🔹 Gemini Full Response for 51_4.txt: "Frightmare","Negative","Acting;Plot;Cinematography","Jeffrey Combs (Actor); Nita Talbot (Actor); Ferdy Mayne (Actor); Christopher Lee (Actor); Porky (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/528_1.txt
# 🎬 Extracting insights for: 528 1
# 🔹 Gemini Full Response for 528_1.txt: "N/A","Negative","Plot;Acting;Soundtrack","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/52_4.txt
# 🎬 Extracting insights for: 52 4
# 🔹 Gemini Full Response for 52_4.txt: "Conrad Radzoff","Negative","Plot;Acting;Soundtrack","Ferdy Mayne (Actor); Jeffrey Combs (Actor); Troma (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/532_3.txt
# 🎬 Extracting insights for: 532 3
# 🔹 Gemini Full Response for 532_3.txt: "The Time Machine (2002)","Negative","Acting;Plot;N/A","Angelina Jolie (Actor); Jack Palance (Actor); Simon Wells (Director); DreamWorks SKG (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/535_4.txt
# 🎬 Extracting insights for: 535 4
# 🔹 Gemini Full Response for 535_4.txt: "Stranded at Third","Negative","Acting;Plot","Tom Selleck (Actor); N/A (Director); N/A (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/537_2.txt
# 🎬 Extracting insights for: 537 2
# 🔹 Gemini Full Response for 537_2.txt: "N/A","Negative","Plot;Animation","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/53_4.txt
# 🎬 Extracting insights for: 53 4
# 🔹 Gemini Full Response for 53_4.txt: "Horror Star","Negative","Plot;Acting;Cinematography","Conrad Radzoff (Actor); Jeffrey Combs (Actor); Ferdy Mayne (Actor); Norman Thaddeus Vane (Director)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/54_3.txt
# 🎬 Extracting insights for: 54 3
# 🔹 Gemini Full Response for 54_3.txt: "Frightmare","Neutral","Acting;Plot;Soundtrack","Ferdinand Mayne (Actor); Jeffrey Combs (Actor); Troma (Studio)","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/neg/552_2.txt
# 🎬 Extracting insights for: 552 2
# 🔹 Gemini Full Response for 552_2.txt: "The Karate Kid","Negative","Acting;Plot","Ralph Macchio (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/554_4.txt
# 🎬 Extracting insights for: 554 4
# 🔹 Gemini Full Response for 554_4.txt: "The Next Karate Kid","Negative","Plot","Ralph Macchio (Actor); Hilary Swank (Actor); Pat Morita (Actor); Robert Mark Kamen (Director); Columbia Pictures (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/556_1.txt
# 🎬 Extracting insights for: 556 1
# 🔹 Gemini Full Response for 556_1.txt: "The Karate Kid (2010)","Negative","Acting;Plot","Hillary Swank (Actor); Pat Morita (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/557_4.txt
# 🎬 Extracting insights for: 557 4
# 🔹 Gemini Full Response for 557_4.txt: "The Next Karate Kid","Neutral","Acting;Plot","Pat Morita (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/563_4.txt
# 🎬 Extracting insights for: 563 4
# 🔹 Gemini Full Response for 563_4.txt: "The Eyes of Alexander","Negative","Plot;Acting;Cinematography","Olivia Hussey (Actor); N/A (Director); N/A (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/569_4.txt
# 🎬 Extracting insights for: 569 4
# 🔹 Gemini Full Response for 569_4.txt: "N/A","Negative","Acting;Plot;Cinematography","Ellen DeGeneres (Actor); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/56_3.txt
# 🎬 Extracting insights for: 56 3
# 🔹 Gemini Full Response for 56_3.txt: "When Bad Writing Happens To Good Actors","Negative","Acting;Plot","Andre Braugher (Actor); David Morse (Actor); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/570_1.txt
# 🎬 Extracting insights for: 570 1
# 🔹 Gemini Full Response for 570_1.txt: "N/A","Negative","Plot;Acting","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/572_3.txt
# 🎬 Extracting insights for: 572 3
# 🔹 Gemini Full Response for 572_3.txt: "N/A","Negative","Acting;Plot","Blythe Danner (Actor); Susan Sarandon (Actor); Kate Capshaw (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/574_4.txt
# 🎬 Extracting insights for: 574 4
# 🔹 Gemini Full Response for 574_4.txt: "Love Letter, The","Negative","Acting;Plot","Tom Selleck (Actor); Alice Drummond (Actor); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/576_4.txt
# 🎬 Extracting insights for: 576 4
# 🔹 Gemini Full Response for 576_4.txt: "N/A","Negative","Plot;Acting;Pacing","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/577_3.txt
# 🎬 Extracting insights for: 577 3
# 🔹 Gemini Full Response for 577_3.txt: "N/A","Negative","Acting;Plot","Ellen Degeneres (Actor); Tom Selleck (Actor); Kate Capshaw (Actor); Everett (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/590_1.txt
# 🎬 Extracting insights for: 590 1
# 🔹 Gemini Full Response for 590_1.txt: "2001: A Space Odyssey","Negative","Plot;Cinematography;Acting","Stanley Kubrick (Director); Keir Dullea (Actor); Gary Lockwood (Actor); Arthur C. Clarke (Writer); MGM (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/592_3.txt
# 🎬 Extracting insights for: 592 3
# 🔹 Gemini Full Response for 592_3.txt: "N/A","Neutral","Plot;Acting;Cinematography","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/594_1.txt
# 🎬 Extracting insights for: 594 1
# 🔹 Gemini Full Response for 594_1.txt: "N/A","Negative","Acting;Plot;Directing","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/596_1.txt
# 🎬 Extracting insights for: 596 1
# 🔹 Gemini Full Response for 596_1.txt: "Evil Behind You","Negative","Acting;Plot;N/A","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/597_4.txt
# 🎬 Extracting insights for: 597 4
# 🔹 Gemini Full Response for 597_4.txt: "N/A","Negative","Plot;Acting;Special Effects","N/A","Frustration","4 stars"
# Processing file: initial-loads/imdb-reviews/neg/609_1.txt
# 🎬 Extracting insights for: 609 1
# 🔹 Gemini Full Response for 609_1.txt: "King of Queens","Negative","Plot;Acting","Kevin James (Actor); Leah Remini (Actor);  (Director)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/610_1.txt
# 🎬 Extracting insights for: 610 1
# 🔹 Gemini Full Response for 610_1.txt: "King of Queens","Negative","Acting;Plot","Kevin James (Actor); Leah Remini (Actor); Jerry Stiller (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/612_3.txt
# 🎬 Extracting insights for: 612 3
# 🔹 Gemini Full Response for 612_3.txt: "The Karen Carpenter Story","Negative","Plot;Acting;Soundtrack","Karen Carpenter (Actor); Tom Burris (Actor); Agnes (Actor); Olive Newton-John (Actor); Phil Ramone (Actor); Itchy (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/613_4.txt
# 🎬 Extracting insights for: 613 4
# 🔹 Gemini Full Response for 613_4.txt: "The Karen Carpenter Story","Negative","Acting;Plot;Soundtrack","Cynthia Gibb (Actor); Agnes Carpenter (Actor); Richard Carpenter (Actor); Karen Carpenter (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/629_4.txt
# 🎬 Extracting insights for: 629 4
# 🔹 Gemini Full Response for 629_4.txt: "L'Auberge Espagnol","Negative","Plot;Acting;N/A","Cédric Klapisch (Director);N/A;N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/633_1.txt
# 🎬 Extracting insights for: 633 1
# 🔹 Gemini Full Response for 633_1.txt: "N/A","Negative","Cinematography;Acting;Plot","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/634_1.txt
# 🎬 Extracting insights for: 634 1
# 🔹 Gemini Full Response for 634_1.txt: "N/A","Negative","Plot;Acting;Special Effects","Diamond Phillips (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/636_1.txt
# 🎬 Extracting insights for: 636 1
# 🔹 Gemini Full Response for 636_1.txt: "N/A","Negative","Acting;Plot;Cinematography","Lou Diamond Phillips (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/651_1.txt
# 🎬 Extracting insights for: 651 1
# 🔹 Gemini Full Response for 651_1.txt: "N/A","Negative","Plot;Acting","N/A","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/neg/655_3.txt
# 🎬 Extracting insights for: 655 3
# 🔹 Gemini Full Response for 655_3.txt: "Nurse Betty","Negative","Acting;Plot","Morgan Freeman (Actor); Chris Rock (Actor); Renee Zellweger (Actor); Greg Kinnear (Actor)","Disappointment","3/10"
# Processing file: initial-loads/imdb-reviews/neg/656_4.txt
# 🎬 Extracting insights for: 656 4
# 🔹 Gemini Full Response for 656_4.txt: "N/A","Negative","Acting;Plot","Morgan Freeman (Actor); Chris Rock (Actor); Renée Zellweger (Actor); Greg Kinnear (Actor);","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/657_1.txt
# 🎬 Extracting insights for: 657 1
# 🔹 Gemini Full Response for 657_1.txt: "N/A","Negative","Acting;Plot;Cinematography","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/668_4.txt
# 🎬 Extracting insights for: 668 4
# 🔹 Gemini Full Response for 668_4.txt: "See No Evil","Neutral","Acting;Plot","Kane (Actor); WWE Films (Studio); Gregory Dark (Director)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/neg/671_3.txt
# 🎬 Extracting insights for: 671 3
# 🔹 Gemini Full Response for 671_3.txt: "The Egyptian","Negative","Acting;Plot","Mika Waltari (Author); Peter Ustinov (Actor); Marlon Brando (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/673_2.txt
# 🎬 Extracting insights for: 673 2
# 🔹 Gemini Full Response for 673_2.txt: "N/A","Negative","N/A","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/674_3.txt
# 🎬 Extracting insights for: 674 3
# 🔹 Gemini Full Response for 674_3.txt: "N/A","Negative","N/A","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/676_1.txt
# 🎬 Extracting insights for: 676 1
# 🔹 Gemini Full Response for 676_1.txt: "America's Next Top Model","Negative","N/A","Tyra Banks (Actor); Jay Manuel (Actor)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/688_4.txt
# 🎬 Extracting insights for: 688 4
# 🔹 Gemini Full Response for 688_4.txt: "The Caper of the Golden Bulls","Neutral","Plot;Acting","Edward G. Robinson (Actor); Robert Wagner (Actor); Raquel Welch (Actor); Vittorio De Sica (Actor); Lucio Fulci (Director); Victor Spinetti (Actor);","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/neg/689_3.txt
# 🎬 Extracting insights for: 689 3
# 🔹 Gemini Full Response for 689_3.txt: "N/A","Negative","Acting;Plot;Cinematography","Humphrey Bogart (Actor); N/A (Director); N/A (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/690_3.txt
# 🎬 Extracting insights for: 690 3
# 🔹 Gemini Full Response for 690_3.txt: "King of the Underworld","Negative","Plot;Acting;N/A","Humphrey Bogart (Actor); Kay Francis (Actor); John Eldredge (Actor); James Stephenson (Actor); Leslie Howard (Actor); Jack Warner (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/693_4.txt
# 🎬 Extracting insights for: 693 4
# 🔹 Gemini Full Response for 693_4.txt: "Wrestlemania 2","Negative","Acting;Plot","Hulk Hogan (Actor);Andre The Giant (Actor);Randy Savage (Actor);British Bulldogs (Actor);Dream Team (Actor);Mr. T (Actor);Roddy Piper (Actor);Lou Albano (Actor);Ozzy Osbourne (Actor);Johnny Valiant (Actor);Tito Santana (Actor);JYD (Actor);Terry Funk (Actor);Jimmy Hart (Actor);Corporal Kirchner (Actor);Nikolai Volkoff (Actor);Classy Freddie Blassie (Actor);Fabulous Moolah (Actor);Velvet Mcintyre (Actor);Paul Orndorff (Actor);Magnificent Muraco (Actor);Mr.Fuji (Actor);George 'The Animal' Steele (Actor);Jake 'The Snake' Roberts (Actor);George Wells (Actor);The Hati Kid (Actor);Joe Frazier (Actor);Lou Duva (Actor);Bob Orton (Actor);William Perry (Actor);Bret Hart (Actor);Hercules Hernandez (Actor);Adrian Adonis (Actor);Uncle Elmer (Actor);King Kong Bundy (Actor)","Disappointment","4/10"
# Processing file: initial-loads/imdb-reviews/neg/694_4.txt
# 🎬 Extracting insights for: 694 4
# 🔹 Gemini Full Response for 694_4.txt: "The Cell","Negative","Acting;Cinematography;Plot","Jennifer Lopez (Actor); Vincent D'Onofrio (Actor); Tarsem Singh (Director)","Frustration","6/10"
# Processing file: initial-loads/imdb-reviews/neg/695_4.txt
# 🎬 Extracting insights for: 695 4
# 🔹 Gemini Full Response for 695_4.txt: "N/A","Negative","Acting;Plot;Cinematography","N/A","Frustration","4/10"
# Processing file: initial-loads/imdb-reviews/neg/696_4.txt
# 🎬 Extracting insights for: 696 4
# 🔹 Gemini Full Response for 696_4.txt: "The Silence of the Lambs","Negative","Plot","Anthony Hopkins (Actor); Jodie Foster (Actor); Jonathan Demme (Director); Orion Pictures (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/69_4.txt
# 🎬 Extracting insights for: 69 4
# 🔹 Gemini Full Response for 69_4.txt: "Witchery","Negative","Gore Effects;Soundtrack;Acting","Linda Blair (Actor); David Hasselhof (Actor); N/A","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/neg/709_4.txt
# 🎬 Extracting insights for: 709 4
# 🔹 Gemini Full Response for 709_4.txt: "Atoll K","Negative","Plot;Acting;N/A","Stan Laurel (Actor); Oliver Hardy (Actor); N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/712_3.txt
# 🎬 Extracting insights for: 712 3
# 🔹 Gemini Full Response for 712_3.txt: "Black Jack","Negative","Acting;Plot;Cinematography","Orson Welles (Director); Agnes Moorehead (Actor); Joseph Cotten (Actor); Suzanne Cloutier (Actor); Dalio (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/713_1.txt
# 🎬 Extracting insights for: 713 1
# 🔹 Gemini Full Response for 713_1.txt: "Fata Morgana","Negative","Cinematography","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/714_4.txt
# 🎬 Extracting insights for: 714 4
# 🔹 Gemini Full Response for 714_4.txt: "Fata Morgana","Negative","Cinematography","Werner Herzog (Director); N/A; N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/716_2.txt
# 🎬 Extracting insights for: 716 2
# 🔹 Gemini Full Response for 716_2.txt: "N/A","Negative","Acting;Plot","Diana Muldaur (Actor); Scott Baio (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/729_1.txt
# 🎬 Extracting insights for: 729 1
# 🔹 Gemini Full Response for 729_1.txt: "Gilmore Girls","Negative","Acting;Plot","Lorelei Gilmore (Actor); Rory Gilmore (Actor); Lauren Graham (Actor); Alexis Bledel (Actor); N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/72_4.txt
# 🎬 Extracting insights for: 72 4
# 🔹 Gemini Full Response for 72_4.txt: "Witchery","Neutral","Acting;Plot;Gore","David Hasselhoff (Actor); Linda Blair (Actor); Fabrizio Laurenti (Director); Joe D'Amato (Producer)","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/neg/730_1.txt
# 🎬 Extracting insights for: 730 1
# 🔹 Gemini Full Response for 730_1.txt: "N/A","Negative","Acting;Plot","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/731_4.txt
# 🎬 Extracting insights for: 731 4
# 🔹 Gemini Full Response for 731_4.txt: "F*ckland","Negative","Cinematography;Plot;Acting","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/732_3.txt
# 🎬 Extracting insights for: 732 3
# 🔹 Gemini Full Response for 732_3.txt: "N/A","Negative","Plot;Acting","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/734_1.txt
# 🎬 Extracting insights for: 734 1
# 🔹 Gemini Full Response for 734_1.txt: "Northanger Abbey","Negative","Acting;Plot;N/A","N/A;N/A;BBC","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/736_2.txt
# 🎬 Extracting insights for: 736 2
# 🔹 Gemini Full Response for 736_2.txt: "Northanger Abbey","Negative","Acting;Plot;N/A","N/A;N/A;N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/737_1.txt
# 🎬 Extracting insights for: 737 1
# 🔹 Gemini Full Response for 737_1.txt: "Northanger Abbey","Negative","Plot;Acting;Soundtrack","Jennifer Ehle (Actor); Douglas McGrath (Director); BBC Films (Studio)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/748_1.txt
# 🎬 Extracting insights for: 748 1
# 🔹 Gemini Full Response for 748_1.txt: "Northanger Abbey","Negative","Soundtrack;Acting;Plot","Peter Firth (Actor); Amanda Root (Actor); Ciaran Hinds (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/751_1.txt
# 🎬 Extracting insights for: 751 1
# 🔹 Gemini Full Response for 751_1.txt: "N/A","Negative","Acting;Plot;Soundtrack","Robert Hardy (Actor); William Shatner (Actor)","Disappointment","0/10"
# Processing file: initial-loads/imdb-reviews/neg/753_2.txt
# 🎬 Extracting insights for: 753 2
# 🔹 Gemini Full Response for 753_2.txt: "Northanger Abbey","Negative","Plot;Acting;N/A","Jane Austen (Author); Henry Tilney (Character)","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/754_2.txt
# 🎬 Extracting insights for: 754 2
# 🔹 Gemini Full Response for 754_2.txt: "Northanger Abbey","Negative","Plot;Acting;N/A","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/neg/755_1.txt
# 🎬 Extracting insights for: 755 1
# 🔹 Gemini Full Response for 755_1.txt: "N/A","Negative","Acting;Plot","N/A","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/neg/756_1.txt
# 🎬 Extracting insights for: 756 1
# 🔹 Gemini Full Response for 756_1.txt: "N/A","Negative","Acting;Plot","Mario Van Peeples (Actor); Mario Van Peeples (Director); Spike Lee (Director)","Frustration","N/A"
# ...
# Processing file: initial-loads/imdb-reviews/pos/954_8.txt
# 🎬 Extracting insights for: 954 8
# 🔹 Gemini Full Response for 954_8.txt: "Ghillie","Positive","Acting;Plot;Cinematography","Vijay (Actor); Trisha (Actor); Prakash Raj (Actor); Dharani (Director)","Satisfaction","8/10"
# Processing file: initial-loads/imdb-reviews/pos/955_10.txt
# 🎬 Extracting insights for: 955 10
# 🔹 Gemini Full Response for 955_10.txt: "N/A","Positive","Acting;Plot;Soundtrack","Vijay (Actor); N/A (Director); N/A (Studio)","Excitement","N/A"
# Processing file: initial-loads/imdb-reviews/pos/956_10.txt
# 🎬 Extracting insights for: 956 10
# 🔹 Gemini Full Response for 956_10.txt: "Gilli","Positive","Acting;Soundtrack;Plot","Vijay (Actor); Trisha (Actor); N/A","Satisfaction","10/10"
# Processing file: initial-loads/imdb-reviews/pos/957_10.txt
# 🎬 Extracting insights for: 957 10
# 🔹 Gemini Full Response for 957_10.txt: "Big Fat Liar","Positive","Acting;Plot;N/A","Frankie Muniz (Actor); Amanda Bynes (Actor); N/A","Nostalgia","10/10"
# Processing file: initial-loads/imdb-reviews/pos/958_10.txt
# 🎬 Extracting insights for: 958 10
# ❌ Error processing 958_10.txt: Cannot get the response text.
# Cannot get the Candidate text.
# Response candidate content has no parts (and thus no text). The candidate is likely blocked by the safety filters.
# Content:
# {}
# Candidate:
# {
#   "finish_reason": "SAFETY",
#   "safety_ratings": [
#     {
#       "category": "HARM_CATEGORY_HATE_SPEECH",
#       "probability": "NEGLIGIBLE",
#       "probability_score": 0.37890625,
#       "severity": "HARM_SEVERITY_LOW",
#       "severity_score": 0.23046875
#     },
#     {
#       "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#       "probability": "NEGLIGIBLE",
#       "probability_score": 0.05493164,
#       "severity": "HARM_SEVERITY_NEGLIGIBLE",
#       "severity_score": 0.09277344
#     },
#     {
#       "category": "HARM_CATEGORY_HARASSMENT",
#       "probability": "MEDIUM",
#       "blocked": true,
#       "probability_score": 0.6875,
#       "severity": "HARM_SEVERITY_MEDIUM",
#       "severity_score": 0.421875
#     },
#     {
#       "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#       "probability": "NEGLIGIBLE",
#       "probability_score": 0.28710938,
#       "severity": "HARM_SEVERITY_LOW",
#       "severity_score": 0.28320312
#     }
#   ]
# }
# Response:
# {
#   "candidates": [
#     {
#       "finish_reason": "SAFETY",
#       "safety_ratings": [
#         {
#           "category": "HARM_CATEGORY_HATE_SPEECH",
#           "probability": "NEGLIGIBLE",
#           "probability_score": 0.37890625,
#           "severity": "HARM_SEVERITY_LOW",
#           "severity_score": 0.23046875
#         },
#         {
#           "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#           "probability": "NEGLIGIBLE",
#           "probability_score": 0.05493164,
#           "severity": "HARM_SEVERITY_NEGLIGIBLE",
#           "severity_score": 0.09277344
#         },
#         {
#           "category": "HARM_CATEGORY_HARASSMENT",
#           "probability": "MEDIUM",
#           "blocked": true,
#           "probability_score": 0.6875,
#           "severity": "HARM_SEVERITY_MEDIUM",
#           "severity_score": 0.421875
#         },
#         {
#           "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#           "probability": "NEGLIGIBLE",
#           "probability_score": 0.28710938,
#           "severity": "HARM_SEVERITY_LOW",
#           "severity_score": 0.28320312
#         }
#       ]
#     }
#   ],
#   "usage_metadata": {
#     "prompt_token_count": 456,
#     "total_token_count": 456
#   },
#   "model_version": "gemini-1.5-flash-001"
# }
# Processing file: initial-loads/imdb-reviews/pos/959_8.txt
# 🎬 Extracting insights for: 959 8
# 🔹 Gemini Full Response for 959_8.txt: "N/A","Positive","Plot;Screenplay","N/A","Satisfaction","8"
# Processing file: initial-loads/imdb-reviews/pos/95_10.txt
# 🎬 Extracting insights for: 95 10
# 🔹 Gemini Full Response for 95_10.txt: "The Hockey Sweater","Positive","Plot;N/A;N/A","Roch Carrier (Writer);N/A;N/A","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/pos/960_8.txt
# 🎬 Extracting insights for: 960 8
# 🔹 Gemini Full Response for 960_8.txt: "Big Fat Liar","Positive","Acting;Plot;Dialogue","Frankie Muniz (Actor); Amanda Bynes (Actor); Paul Giamatti (Actor); Shawn Levy (Director); Kenan Thompson (Actor); Jaleel White (Actor)","Excitement","N/A"
# Processing file: initial-loads/imdb-reviews/pos/961_8.txt
# 🎬 Extracting insights for: 961 8
# 🔹 Gemini Full Response for 961_8.txt: "N/A","Positive","Plot;Acting","N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/962_9.txt
# 🎬 Extracting insights for: 962 9
# 🔹 Gemini Full Response for 962_9.txt: "Fun movie! Great for the kids - they found it very entertaining. Somewhat predictable, but there are a few surprises. Great movie to watch if you're looking for something just to entertain (don't expect to be seeing a classic!)","Positive","Plot;Acting","N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/963_8.txt
# 🎬 Extracting insights for: 963 8
# 🔹 Gemini Full Response for 963_8.txt: "N/A","Positive","Acting;Plot","N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/964_7.txt
# 🎬 Extracting insights for: 964 7
# 🔹 Gemini Full Response for 964_7.txt: "Big Fat Liar","Positive","Acting;Plot","Frankie Muniz (Actor); Amanda Bynes (Actor); Universal Studios (Studio)","Satisfaction","B-"
# Processing file: initial-loads/imdb-reviews/pos/965_9.txt
# 🎬 Extracting insights for: 965 9
# 🔹 Gemini Full Response for 965_9.txt: "Big Fat Liar","Positive","Plot;Acting","Frankie Muniz (Actor); Amanda Bynes (Actor); Paul Giamatti (Actor)","N/A","N/A"
# Processing file: initial-loads/imdb-reviews/pos/966_10.txt
# 🎬 Extracting insights for: 966 10
# 🔹 Gemini Full Response for 966_10.txt: "Big Fat Liar","Negative","Plot;Acting","Frankie Muniz (Actor); Paul Giamatti (Actor); Amanda Bynes (Actor); Shawn Levy (Director); 20th Century Fox (Studio)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/967_7.txt
# 🎬 Extracting insights for: 967 7
# 🔹 Gemini Full Response for 967_7.txt: "Big Fat Liar","Positive","Acting;Plot;N/A","Frankie Muniz (Actor); Paul Giamatti (Actor); N/A","Excitement","***/****"
# Processing file: initial-loads/imdb-reviews/pos/968_8.txt
# 🎬 Extracting insights for: 968 8
# 🔹 Gemini Full Response for 968_8.txt: "Big Fat Liar","Positive","Acting;Plot;N/A","Frankie Muniz (Actor); Paul Weitz (Director); Marty Wolfe (Actor); Universal Pictures (Studio)","Excitement","N/A"
# Processing file: initial-loads/imdb-reviews/pos/969_9.txt
# 🎬 Extracting insights for: 969 9
# 🔹 Gemini Full Response for 969_9.txt: "BIG FAT LIAR","Positive","Acting;Plot","Frankie Muniz (Actor); Amanda Bynes (Actor); Paul Giamatti (Actor); Jaleel White (Actor)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/96_10.txt
# 🎬 Extracting insights for: 96 10
# 🔹 Gemini Full Response for 96_10.txt: "N/A","Positive","Animation;Nostalgia;Plot","N/A","Nostalgia","10 out of 10"
# Processing file: initial-loads/imdb-reviews/pos/970_7.txt
# 🎬 Extracting insights for: 970 7
# 🔹 Gemini Full Response for 970_7.txt: "Big Fat Liar","Positive","Plot;Acting;N/A","Frankie Muniz (Actor); Paul Giamatti (Actor); Amanda Bynes (Actor); N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/971_10.txt
# 🎬 Extracting insights for: 971 10
# 🔹 Gemini Full Response for 971_10.txt: "Big Fat Liar","Positive","Plot;Soundtrack","Frankie Muniz (Actor); Amanda Bynes (Actor); Paul Weitz (Director); Universal Pictures (Studio)","Excitement","N/A"
# Processing file: initial-loads/imdb-reviews/pos/972_7.txt
# 🎬 Extracting insights for: 972 7
# 🔹 Gemini Full Response for 972_7.txt: "N/A","Positive","Acting;Plot;Soundtrack","N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/973_10.txt
# 🎬 Extracting insights for: 973 10
# 🔹 Gemini Full Response for 973_10.txt: "Big Fat Liar","Positive","Plot;Acting;N/A","Marty Wolf (Producer); Jason Shepherd (Actor); Kaylee (Actor); Frank Jackson (Actor); Jaleel (Actor); Lester (Actor); Monty (Assistant); Rocco (Security Guard); N/A","Excitement","N/A"
# Processing file: initial-loads/imdb-reviews/pos/974_10.txt
# 🎬 Extracting insights for: 974 10
# 🔹 Gemini Full Response for 974_10.txt: "N/A","Positive","Plot;Acting","N/A","Excitement","N/A"
# Processing file: initial-loads/imdb-reviews/pos/975_7.txt
# 🎬 Extracting insights for: 975 7
# 🔹 Gemini Full Response for 975_7.txt: "N/A","Positive","Acting;Plot","Paul Giamatti (Actor); Lee Majors (Actor); Jaleel White (Actor); Amanda Bynes (Actor); Frankie Muniz (Actor)","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/pos/976_8.txt
# 🎬 Extracting insights for: 976 8
# 🔹 Gemini Full Response for 976_8.txt: "Big Fat Liar","Positive","Plot","Frankie Muniz (Actor); Amanda Bynes (Actor); Paul Weitz (Director); Universal Pictures (Studio)","Satisfaction","5.2/10"
# Processing file: initial-loads/imdb-reviews/pos/977_9.txt
# 🎬 Extracting insights for: 977 9
# 🔹 Gemini Full Response for 977_9.txt: "N/A","Positive","Acting;Plot","Paul Giamatti (Actor);N/A;N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/978_7.txt
# 🎬 Extracting insights for: 978 7
# 🔹 Gemini Full Response for 978_7.txt: "Agent Cody Banks","Positive","Acting;Plot","Frankie Muniz (Actor); Amanda Bynes (Actor); Paul Giamatti (Actor);","Excitement","N/A"
# Processing file: initial-loads/imdb-reviews/pos/979_10.txt
# 🎬 Extracting insights for: 979 10
# 🔹 Gemini Full Response for 979_10.txt: "Big Fat Liar","Positive","Acting;Plot;N/A","Amanda Bynes (Actor); Frankie Muniz (Actor); Lee Majors (Actor); Paul Weitz (Director); Universal Pictures (Studio)","Excitement","N/A"
# Processing file: initial-loads/imdb-reviews/pos/97_7.txt
# 🎬 Extracting insights for: 97 7
# 🔹 Gemini Full Response for 97_7.txt: "N/A","Negative","Plot","Leonard Maltin (Critic); National Film Board of Canada (Studio)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/pos/980_7.txt
# 🎬 Extracting insights for: 980 7
# 🔹 Gemini Full Response for 980_7.txt: "N/A","Positive","Acting;Plot;N/A","Malcolm in the Middle (TV Series); Lee Majors (Actor); Jamiel (Actor)","Nostalgia","3.5/5"
# Processing file: initial-loads/imdb-reviews/pos/981_9.txt
# 🎬 Extracting insights for: 981 9
# 🔹 Gemini Full Response for 981_9.txt: "Big Fat Liar","Positive","Acting;Plot;N/A","Frankie Muniz (Actor); Sandra Oh (Actor); Paul Giamatti (Actor); Dan Schneider (Producer); Brian Robbins (Producer); Amanda Bynes (Actor); Amanda Detmer (Actor); Donald Faison (Actor); Jaleel White (Actor); Lee Majors (Actor); Nickelodeon (Studio); Universal Studios (Studio)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/982_8.txt
# 🎬 Extracting insights for: 982 8
# 🔹 Gemini Full Response for 982_8.txt: "N/A","Positive","Acting;Plot","Amanda (Actor)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/983_7.txt
# 🎬 Extracting insights for: 983 7
# 🔹 Gemini Full Response for 983_7.txt: "N/A","Positive","Acting;Plot;N/A","Frankie Muniz (Actor); Amanda Bines (Actor); N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/984_8.txt
# 🎬 Extracting insights for: 984 8
# 🔹 Gemini Full Response for 984_8.txt: "N/A","Positive","Acting;Plot;Special Effects","N/A","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/pos/985_10.txt
# 🎬 Extracting insights for: 985 10
# 🔹 Gemini Full Response for 985_10.txt: "N/A","Positive","Acting;Plot;Cinematography","N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/986_10.txt
# 🎬 Extracting insights for: 986 10
# 🔹 Gemini Full Response for 986_10.txt: "N/A","Positive","Acting;Cinematography","N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/987_7.txt
# 🎬 Extracting insights for: 987 7
# 🔹 Gemini Full Response for 987_7.txt: "N/A","Positive","Plot;Acting","N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/988_8.txt
# 🎬 Extracting insights for: 988 8
# 🔹 Gemini Full Response for 988_8.txt: "N/A","Positive","Cinematography;Acting;Plot","Keira Knightley (Actor); N/A (Director); N/A (Studio)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/989_7.txt
# 🎬 Extracting insights for: 989 7
# 🔹 Gemini Full Response for 989_7.txt: "The  Edge of Love","Negative","Acting;Plot;Soundtrack","Keira Knightley (Actor); Dylan Thomas (Actor); Matthew Rhys (Actor)","Disappointment","N/A"
# Processing file: initial-loads/imdb-reviews/pos/98_9.txt
# 🎬 Extracting insights for: 98 9
# 🔹 Gemini Full Response for 98_9.txt: "The Unkind Critic","Negative","Plot;Acting","N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/pos/990_7.txt
# 🎬 Extracting insights for: 990 7
# 🔹 Gemini Full Response for 990_7.txt: "The Edge of Love","Positive","Cinematography;Acting;Plot","Dylan Thomas (Actor); Keira Knightley (Actor); Sienna Miller (Actor); Matthew Rhys (Actor); Joe Wright (Director)","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/pos/991_7.txt
# 🎬 Extracting insights for: 991 7
# 🔹 Gemini Full Response for 991_7.txt: "Dylan Thomas: The Life and Times","Positive","Acting;Plot;Themes","N/A","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/992_7.txt
# 🎬 Extracting insights for: 992 7
# 🔹 Gemini Full Response for 992_7.txt: "N/A","Positive","Acting;Plot;N/A","Cillian Murphy (Actor); Matthew Rhys (Actor); Sienna Miller (Actor); Keira Knightley (Actor); Suggs (Actor)","Frustration","7/10"
# Processing file: initial-loads/imdb-reviews/pos/993_8.txt
# 🎬 Extracting insights for: 993 8
# 🔹 Gemini Full Response for 993_8.txt: "N/A","Positive","Acting;Plot;N/A","Kiera Knightley (Actor); Cillian Murphy (Actor); Dylan Thomas (Actor)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/994_7.txt
# 🎬 Extracting insights for: 994 7
# 🔹 Gemini Full Response for 994_7.txt: "The Edge of Love","Positive","Acting;Plot;Cinematography","Matthew Rhys (Actor); Keira Knightley (Actor); Sienna Miller (Actor); Cillian Murphy (Actor); John Maybury (Director); N/A","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/pos/995_7.txt
# 🎬 Extracting insights for: 995 7
# 🔹 Gemini Full Response for 995_7.txt: "N/A","Positive","Acting;Cinematography;Plot","Keira Knightley (Actor); Sienna Miller (Actor); N/A","Frustration","N/A"
# Processing file: initial-loads/imdb-reviews/pos/996_7.txt
# 🎬 Extracting insights for: 996 7
# 🔹 Gemini Full Response for 996_7.txt: "N/A","Positive","Plot;Acting;N/A","Keira Knightley (Actor); Sienna Miller (Actor); Matthew Rhys (Actor)","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/pos/997_7.txt
# 🎬 Extracting insights for: 997 7
# 🔹 Gemini Full Response for 997_7.txt: "The Edge of Love","Positive","Acting;Plot;Emotional Tone","Matthew Rhys (Actor); Sienna Miller (Actor); Keira Knightley (Actor); Cillian Murphy (Actor); John Maybury (Director)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/998_7.txt
# 🎬 Extracting insights for: 998 7
# 🔹 Gemini Full Response for 998_7.txt: "N/A","Positive","Plot;Acting","Dylan Thomas (Actor); Vera (Actor)","Nostalgia","N/A"
# Processing file: initial-loads/imdb-reviews/pos/999_8.txt
# 🎬 Extracting insights for: 999 8
# 🔹 Gemini Full Response for 999_8.txt: "The Edge Of Love","Positive","Acting;Cinematography;Plot","Sienna Miller (Actor); Keira Knightley (Actor); Matthew Rhys (Actor); Cillian Murphy (Actor); Jonathan Freeman (Cinematographer); John Maybury (Director)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/99_10.txt
# 🎬 Extracting insights for: 99 10
# 🔹 Gemini Full Response for 99_10.txt: "N/A","Positive","Acting;Cinematography;Plot","Tom Noonan (Actor); Tobias Wolff (Writer)","Satisfaction","N/A"
# Processing file: initial-loads/imdb-reviews/pos/9_7.txt
# 🎬 Extracting insights for: 9 7
# 🔹 Gemini Full Response for 9_7.txt: "The Guardian","Positive","Acting;Plot;Cinematography","Kevin Costner (Actor); Ashton Kutcher (Actor); Sela Ward (Actor)","Satisfaction","N/A"
# ✅ Uploaded single combined file: initial-loads/imdb-reviews/out/all_imdb_reviews.csv
