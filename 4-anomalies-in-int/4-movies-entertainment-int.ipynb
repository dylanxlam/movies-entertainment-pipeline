# %%
from google.cloud import bigquery

project_id = "dylanericsp25"
dataset = "movies_entertainment_int"
region = "us-central1"

bq_client = bigquery.Client()

dataset_id = bigquery.Dataset(f"{project_id}.{dataset}")
dataset_id.location = region
resp = bq_client.create_dataset(dataset_id, exists_ok=True)
print("Created dataset {}.{}".format(bq_client.project, resp.dataset_id))
# Out:
# Created dataset dylanericsp25.movies_entertainment_int

# %%
# %load_ext google.cloud.bigquery
# Out:
# /Users/dylanlam/miniconda3/lib/python3.11/site-packages/google/cloud/bigquery/__init__.py:237: FutureWarning: %load_ext google.cloud.bigquery is deprecated. Install bigquery-magics package and use `%load_ext bigquery_magics`, instead.
#   warnings.warn(

# %% [markdown]
# ### **Criteria 8:**
# There exists a table in the raw layer of the warehouse that stores a list of elements in a cell.
# - This happens when multiple values are stored in one cell instead of separate rows:
#     1. movies_metadata.csv → The "genres" column stores: "[{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}]"
#     2. Instead of separate rows, genres are stored as lists inside a single cell. Thus, this criterion is fulfilled.

# %%
# %%bigquery
# select adult, budget, genres, split(genres, ',') as genres_array
# from movies_entertainment_stg.movies_metadata
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        adult    budget                            genres  \
# 0      FALSE         0       Action, War, Drama, History
# 1      FALSE         0                             Drama
# 2      FALSE         0                             Drama
# 3      FALSE         0                  Drama, Adventure
# 4      FALSE         0            Action, Crime, Romance
# ...      ...       ...                               ...
# 45458  FALSE         0                             Drama
# 45459  FALSE   2500000  Drama, Horror, Thriller, Foreign
# 45460  FALSE         0                    Drama, Romance
# 45461  FALSE  31000000                    Drama, Romance
# 45462  FALSE         0               War, Drama, History
#
#                                 genres_array
# 0           [Action,  War,  Drama,  History]
# 1                                    [Drama]
# 2                                    [Drama]
# 3                        [Drama,  Adventure]
# 4                 [Action,  Crime,  Romance]
# ...                                      ...
# 45458                                [Drama]
# 45459  [Drama,  Horror,  Thriller,  Foreign]
# 45460                      [Drama,  Romance]
# 45461                      [Drama,  Romance]
# 45462                [War,  Drama,  History]
#
# [45463 rows x 4 columns]

# %%
# %%bigquery
# with genres as (select split(genres, ',') as genres_array,adult,
#     budget,
#     id,
#     imdb_id,
#     original_language,
#     original_title,
#     overview,
#     _data_source,
#     _load_time
#                     from movies_entertainment_stg.movies_metadata)
# select
#     adult,
#     budget,
#     genre,
#     id,
#     imdb_id,
#     original_language,
#     original_title,
#     overview,
#     _data_source,
#     _load_time
# from genres, unnest(genres_array) as genre
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        adult    budget     genre      id    imdb_id original_language  \
# 0      FALSE         0    Action  104473  tt0223958           Unknown
# 1      FALSE         0       War  104473  tt0223958           Unknown
# 2      FALSE         0     Drama  104473  tt0223958           Unknown
# 3      FALSE         0   History  104473  tt0223958           Unknown
# 4      FALSE         0     Drama   44284  tt0111055                ar
# ...      ...       ...       ...     ...        ...               ...
# 91089  FALSE  31000000     Drama  121602  tt2071441                zh
# 91090  FALSE  31000000   Romance  121602  tt2071441                zh
# 91091  FALSE         0       War   34561  tt0363290                zh
# 91092  FALSE         0     Drama   34561  tt0363290                zh
# 91093  FALSE         0   History   34561  tt0363290                zh
#
#               original_title  \
# 0      La prise de Tournavos
# 1      La prise de Tournavos
# 2      La prise de Tournavos
# 3      La prise de Tournavos
# 4                 صمت القصور
# ...                      ...
# 91089                   危險關係
# 91090                   危險關係
# 91091                    紫蝴蝶
# 91092                    紫蝴蝶
# 91093                    紫蝴蝶
#
#                                                 overview        _data_source  \
# 0      Three military men, seen inside a fortificatio...  the-movies-dataset
# 1      Three military men, seen inside a fortificatio...  the-movies-dataset
# 2      Three military men, seen inside a fortificatio...  the-movies-dataset
# 3      Three military men, seen inside a fortificatio...  the-movies-dataset
# 4      The death of a prince brings a young woman bac...  the-movies-dataset
# ...                                                  ...                 ...
# 91089  Dangerous Liaisons is a Chinese film by Hur Ji...  the-movies-dataset
# 91090  Dangerous Liaisons is a Chinese film by Hur Ji...  the-movies-dataset
# 91091  Ding Hui is a member of Purple Butterfly, a po...  the-movies-dataset
# 91092  Ding Hui is a member of Purple Butterfly, a po...  the-movies-dataset
# 91093  Ding Hui is a member of Purple Butterfly, a po...  the-movies-dataset
#
#                             _load_time
# 0     2025-02-06 22:48:24.489026+00:00
# 1     2025-02-06 22:48:24.489026+00:00
# 2     2025-02-06 22:48:24.489026+00:00
# 3     2025-02-06 22:48:24.489026+00:00
# 4     2025-02-06 22:48:24.489026+00:00
# ...                                ...
# 91089 2025-02-06 22:48:24.489026+00:00
# 91090 2025-02-06 22:48:24.489026+00:00
# 91091 2025-02-06 22:48:24.489026+00:00
# 91092 2025-02-06 22:48:24.489026+00:00
# 91093 2025-02-06 22:48:24.489026+00:00
#
# [91094 rows x 10 columns]

# %%
# %%bigquery
# create or replace table movies_entertainment_int.Movies_Metadata as
#     with genres as (select split(genres, ',') as genres_array,adult,
#         budget,
#         id,
#         imdb_id,
#         original_language,
#         original_title,
#         overview,
#         _data_source,
#         _load_time
#                         from movies_entertainment_stg.movies_metadata)
#     select
#         adult,
#         budget,
#         genre,
#         id,
#         imdb_id,
#         original_language,
#         original_title,
#         overview,
#         _data_source,
#         _load_time
#     from genres, unnest(genres_array) as genre
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### **Criteria 9:**
# There exists two tables in the raw layer of the warehouse which originated from different sources and which have similar data. These tables use two different identifier systems to refer to the same entity.
# - Met – the results show that the same movie title appears with different movie_id values across datasets:
#     1. "A Perfect Man" appears with movie_id = 2 in at least two different places.
#     2. "Aftermath" appears under at least six different IDs.
#     3. "Bad Boys" has four different IDs.
#     4. This confirms that the same movie is being referenced with different unique identifiers across movies_metadata.csv and netflix_titles.csv.

# %%
# %%bigquery
# select m.id, m.original_title, n.show_id, n.title
# from movies_entertainment_stg.movies_metadata m
# inner join movies_entertainment_stg.netflix_movies_and_tvshows n
# on m.original_title = n.title
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           id     original_title show_id              title
# 0        523            Requiem   s4974            Requiem
# 1      55587            Michael   s2280            Michael
# 2     124639             Target   s4376             Target
# 3     107937              Bhoot   s6300              Bhoot
# 4      29621               Solo   s4205               Solo
# ...      ...                ...     ...                ...
# 2483  191112    Premachi Goshta   s7792    Premachi Goshta
# 2484  369033            Rebirth   s5831            Rebirth
# 2485  206157  Into the Badlands   s4029  Into the Badlands
# 2486  336807             Fatima   s1367             Fatima
# 2487   20088           Kon-Tiki   s7224           Kon-Tiki
#
# [2488 rows x 4 columns]

# %%
# %%bigquery
# select CASE when SAFE_CAST(movie_id as string) IS NULL THEN netflix_id ELSE SAFE_CAST(movie_id as string) END AS id,
# original_title,
# type,
# director,
# group_cast,
# country,
# date_added,
# release_year,
# rating,
# duration,
# _data_source,
# _load_time
# from
#     (select * from
#         (select m.id as movie_id, n.title, n.type, n.director, n.cast as group_cast, n.country, n.date_added, n.release_year, n.rating, n.duration, n._data_source, n._load_time
#         from movies_entertainment_stg.movies_metadata m
#         inner join movies_entertainment_stg.netflix_movies_and_tvshows n
#         on m.original_title = n.title) t1
#     right join (select n.show_id as netflix_id, n.title as original_title from movies_entertainment_stg.netflix_movies_and_tvshows n) t2
#     on t1.title = t2.original_title)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           id                       original_title     type  \
# 0        252  Willy Wonka & the Chocolate Factory    Movie
# 1       5255                    The Polar Express    Movie
# 2     123723                                 Gigi    Movie
# 3      17281                                 Gigi    Movie
# 4      17529                            True Grit    Movie
# ...      ...                                  ...      ...
# 9160   96599                                 Eden  TV Show
# 9161  360339                                 Eden  TV Show
# 9162  104528                                 Dogs  TV Show
# 9163  428501                       City of Ghosts  TV Show
# 9164   31932                       City of Ghosts  TV Show
#
#                                 director  \
# 0                             Mel Stuart
# 1                        Robert Zemeckis
# 2     Vincente Minnelli, Charles Walters
# 3     Vincente Minnelli, Charles Walters
# 4                         Henry Hathaway
# ...                                  ...
# 9160                                None
# 9161                                None
# 9162                                None
# 9163                                None
# 9164                                None
#
#                                              group_cast  \
# 0     Gene Wilder, Jack Albertson, Peter Ostrum, Roy...
# 1     Tom Hanks, Leslie Zemeckis, Eddie Deezen, Nona...
# 2     Leslie Caron, Maurice Chevalier, Louis Jourdan...
# 3     Leslie Caron, Maurice Chevalier, Louis Jourdan...
# 4     John Wayne, Glen Campbell, Kim Darby, Jeremy S...
# ...                                                 ...
# 9160  Marika Kono, Kentaro Ito, Kyoko Hikami, Tarusu...
# 9161  Marika Kono, Kentaro Ito, Kyoko Hikami, Tarusu...
# 9162                                               None
# 9163  August Nuñez, Blue Chapman, Kirikou S'hai Muld...
# 9164  August Nuñez, Blue Chapman, Kirikou S'hai Muld...
#
#                                         country  date_added release_year  \
# 0     United States, East Germany, West Germany  2020-01-01         1971
# 1                                 United States  2021-01-01         2004
# 2                                 United States  2019-11-01         1958
# 3                                 United States  2019-11-01         1958
# 4                                 United States  2020-01-01         1969
# ...                                         ...         ...          ...
# 9160                                       None  2021-05-27         2021
# 9161                                       None  2021-05-27         2021
# 9162                              United States  2021-07-07         2021
# 9163                              United States  2021-03-05         2021
# 9164                              United States  2021-03-05         2021
#
#      rating   duration                 _data_source  \
# 0         G    100 min  netflix-movies-and-tv-shows
# 1         G    100 min  netflix-movies-and-tv-shows
# 2         G    115 min  netflix-movies-and-tv-shows
# 3         G    115 min  netflix-movies-and-tv-shows
# 4         G    128 min  netflix-movies-and-tv-shows
# ...     ...        ...                          ...
# 9160  TV-PG   1 Season  netflix-movies-and-tv-shows
# 9161  TV-PG   1 Season  netflix-movies-and-tv-shows
# 9162  TV-PG  2 Seasons  netflix-movies-and-tv-shows
# 9163  TV-Y7   1 Season  netflix-movies-and-tv-shows
# 9164  TV-Y7   1 Season  netflix-movies-and-tv-shows
#
#                            _load_time
# 0    2025-02-05 03:16:45.466701+00:00
# 1    2025-02-05 03:16:45.466701+00:00
# 2    2025-02-05 03:16:45.466701+00:00
# 3    2025-02-05 03:16:45.466701+00:00
# 4    2025-02-05 03:16:45.466701+00:00
# ...                               ...
# 9160 2025-02-05 03:16:45.466701+00:00
# 9161 2025-02-05 03:16:45.466701+00:00
# 9162 2025-02-05 03:16:45.466701+00:00
# 9163 2025-02-05 03:16:45.466701+00:00
# 9164 2025-02-05 03:16:45.466701+00:00
#
# [9165 rows x 12 columns]

# %%
# %%bigquery
# create or replace table movies_entertainment_int.Netflix_Movies_And_Tvshows AS
#     select CASE when SAFE_CAST(movie_id as string) IS NULL THEN netflix_id ELSE SAFE_CAST(movie_id as string) END AS id,
#     original_title,
#     original_type,
#     original_director,
#     original_cast,
#     original_country,
#     original_date_added,
#     original_release_year,
#     original_rating,
#     original_duration,
#     original_data_source,
#     original_load_time
#     from
#         (select * from
#             (select m.id as movie_id, n.title, n.type, n.director, n.cast as group_cast, n.country, n.date_added, n.release_year, n.rating, n.duration, n._data_source, n._load_time
#             from movies_entertainment_stg.movies_metadata m
#             inner join movies_entertainment_stg.netflix_movies_and_tvshows n
#             on m.original_title = n.title) t1
#         right join (select n.show_id as netflix_id, n.title as original_title, n.type as original_type, n.director as original_director, n.cast as original_cast, n.country as original_country, n.date_added as original_date_added, n.release_year as original_release_year, n.rating as original_rating, n.duration as original_duration, n._data_source as original_data_source, n._load_time as original_load_time from movies_entertainment_stg.netflix_movies_and_tvshows n) t2
#         on t1.title = t2.original_title)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### **Criteria 10**
#
# There exists a table in the raw layer of the warehouse that models more than one logical entity in the same table. This leads to data redundancy and storing repeated values.
# - Yes - some tables store multiple logical entities together, causing redundancy: box_office_gross contained entities of companies and movies
#
# **Goal: Decompose box_office_gross into companies and box_office_gross**

# %%
# %%bigquery
# select brand, total, releases
# from movies_entertainment_stg.box_office_gross
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                   brand        total  releases
# 0                            Alan Moore    276088604         4
# 1                          MonsterVerse    580145113         4
# 2                         Broken Lizard     73338237         5
# 3                         Robert Ludlum    645459186         6
# 4                                 Laika    300158323         6
# 5                            Roald Dahl    356238494         7
# 6                    DisneyToon Studios    337576791         8
# 7                        Disney Channel    359952780         8
# 8                Warner Animation Group    786497181         8
# 9                          Disneynature    151620585         8
# 10               Tim Burton-Johnny Depp    889955830         8
# 11                         Clive Barker    171686009        10
# 12                         John Grisham    645661825        10
# 13                        Hanna-Barbera    578586146        10
# 14                      Nicholas Sparks    574728259        11
# 15                  Saturday Night Live    346533876        11
# 16           Illumination Entertainment   2759505881        13
# 17                             Blue Sky   1740428763        13
# 18                       Philip K. Dick    495237720        14
# 19        Walt Disney Animation Studios   2774912904        15
# 20                          Tyler Perry    765635362        16
# 21                              Aardman    333777829        16
# 22                    Dark Horse Comics    947671338        16
# 23                          Dark Castle    454625110        16
# 24                               Hasbro   2079485824        17
# 25                     National Lampoon    436669213        21
# 26              Sony Pictures Animation   1918763863        21
# 27                          Nickelodeon   1930746182        26
# 28                        Studio Ghibli     70666453        26
# 29                                Pixar   6078217662        28
# 30                            CBS Films    652824187        29
# 31  Saturday Night Live - Alumni Debuts   1023596031        30
# 32                                  MTV   1520456359        36
# 33                         Walden Media   1842852183        38
# 34                            Lucasfilm   6325022918        39
# 35                 DreamWorks Animation   5792217737        41
# 36                       Amazon Studios    204376048        43
# 37                            DC Comics   5815645953        46
# 38                         Stephen King   1729648950        49
# 39                Blumhouse Productions   2451844676        49
# 40                   Legendary Pictures   7018798067        56
# 41                        Marvel Comics  15806336901        69

# %%
# %%bigquery
# create or replace table movies_entertainment_int.Companies as
#     select brand, total, releases
#     from movies_entertainment_stg.box_office_gross
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# create or replace table movies_entertainment_int.Box_Office_Gross as
#     select brand, number_1_release, lifetime_gross, _data_source, _load_time
#     from movies_entertainment_stg.box_office_gross
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# IMDB Reviews Intermediate

# %%
# %%bigquery
# create or replace table movies_entertainment_int.Imdb_Reviews as
#     select *
#     from movies_entertainment_stg.imdb_reviews
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#     select brand, number_1_release, lifetime_gross, _data_source, _load_time from
#         (select t2.id, t2.original_title, t1.brand, t1.number_1_release, t1.lifetime_gross, t1._data_source, t1._load_time
#         from movies_entertainment_stg.box_office_gross t1 inner join movies_entertainment_int.Movies_Metadata t2 on t1.number_1_release = t2.original_title)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             brand       number_1_release  lifetime_gross      _data_source  \
# 0    Disneynature                  Earth        32011576  box-office-gross
# 1  Amazon Studios  Manchester by the Sea        47695371  box-office-gross
#
#                         _load_time
# 0 2025-02-06 23:13:06.561261+00:00
# 1 2025-02-06 23:13:06.561261+00:00

# %% [markdown]
# **Removing Duplicate movies with diff IDs**

# %%
# %%bigquery
# CREATE OR REPLACE TABLE movies_entertainment_int.Movies_Metadata AS
# WITH duplicates AS (
#     SELECT original_title
#     FROM movies_entertainment_int.Movies_Metadata
#     GROUP BY original_title
#     HAVING COUNT(*) > 1
# )
# SELECT *
# FROM movies_entertainment_int.Movies_Metadata
# WHERE original_title NOT IN (SELECT original_title FROM duplicates)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### **Removing Duplicates from box office gross**

# %%
# %%bigquery
# delete from movies_entertainment_int.Box_Office_Gross where brand in ('Platinum Dunes', 'Vertigo Entertainment', 'Bad Robot')
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#     select id, brand, number_1_release, lifetime_gross, _data_source, _load_time from
#         (select t2.id, t2.original_title, t1.brand, t1.number_1_release, t1.lifetime_gross, t1._data_source, t1._load_time
#         from movies_entertainment_stg.box_office_gross t1 inner join movies_entertainment_int.Movies_Metadata t2 on t1.number_1_release = t2.original_title)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          id                   brand                    number_1_release  \
# 0     12092  Tim Burton-Johnny Depp                 Alice in Wonderland
# 1     25694  Tim Burton-Johnny Depp                 Alice in Wonderland
# 2       809    DreamWorks Animation                             Shrek 2
# 3      1498          Platinum Dunes        Teenage Mutant Ninja Turtles
# 4      1498             Nickelodeon        Teenage Mutant Ninja Turtles
# ..      ...                     ...                                 ...
# 146     809    DreamWorks Animation                             Shrek 2
# 147   11887          Disney Channel  High School Musical 3: Senior Year
# 148     118              Roald Dahl   Charlie and the Chocolate Factory
# 149  137106  Warner Animation Group                      The Lego Movie
# 150   15670             Tyler Perry                  Madea Goes to Jail
#
#      lifetime_gross      _data_source                       _load_time
# 0         334191110  box-office-gross 2025-02-06 23:13:06.561261+00:00
# 1         334191110  box-office-gross 2025-02-06 23:13:06.561261+00:00
# 2         441226247  box-office-gross 2025-02-06 23:13:06.561261+00:00
# 3         191204754  box-office-gross 2025-02-06 23:13:06.561261+00:00
# 4         191204754  box-office-gross 2025-02-06 23:13:06.561261+00:00
# ..              ...               ...                              ...
# 146       441226247  box-office-gross 2025-02-06 23:13:06.561261+00:00
# 147        90559416  box-office-gross 2025-02-06 23:13:06.561261+00:00
# 148       206459076  box-office-gross 2025-02-06 23:13:06.561261+00:00
# 149       257760692  box-office-gross 2025-02-06 23:13:06.561261+00:00
# 150        90508336  box-office-gross 2025-02-06 23:13:06.561261+00:00
#
# [151 rows x 6 columns]

# %% [markdown]
# #### **Intermediate table for Box Office Gross ensuring priumary key is id**

# %%
# %%bigquery
# CREATE OR REPLACE TABLE movies_entertainment_int.Box_Office_Gross AS
# select id, brand, number_1_release, lifetime_gross, _data_source, _load_time from
#     (select t2.id, t2.original_title, t1.brand, t1.number_1_release, t1.lifetime_gross, t1._data_source, t1._load_time
#     from movies_entertainment_stg.box_office_gross t1 inner join movies_entertainment_stg.movies_metadata t2 on t1.number_1_release = t2.original_title)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### **Primary Key Constraints**

# %%
# %%bigquery
# alter table movies_entertainment_int.Box_Office_Gross add primary key (id) not enforced;
# alter table movies_entertainment_int.Movies_Metadata add primary key (id) not enforced;
# alter table movies_entertainment_int.Netflix_Movies_And_Tvshows add primary key (id) not enforced;
# alter table movies_entertainment_int.Companies add primary key (brand) not enforced
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# alter table movies_entertainment_int.Box_Office_Gross add constraint box_office_gross_fk_companies foreign key (brand)
#     references movies_entertainment_int.Companies (brand) not enforced;
# Out:
# Executing query with job ID: bd715a99-b51e-4522-a635-9a9818d0c74b
# Query executing: 0.26s
# ERROR:
#  409 GET https://bigquery.googleapis.com/bigquery/v2/projects/dylanericsp25/queries/bd715a99-b51e-4522-a635-9a9818d0c74b?maxResults=0&location=us-central1&prettyPrint=false: Already Exists: Constraint box_office_gross_fk_companies
#
# Location: us-central1
# Job ID: bd715a99-b51e-4522-a635-9a9818d0c74b
